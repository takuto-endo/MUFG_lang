# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# %cd /content/drive/MyDrive/_MUFG_student
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/_MUFG_student

# %%
import numpy as np
import pandas as pd
import os

# %%
path_a = './outputs/Exp002_microsoft/deberta-base/preds'
local_sub_a = np.load(os.path.join(path_a, 'sub_pred.npy'))
sub_a = pd.read_csv(os.path.join(path_a, 'Exp002_CV8058817912_submission.csv'))

path_b = './outputs/Exp002_saint/preds'
local_sub_b = np.load(os.path.join(path_b, 'sub_pred.npy'))
sub_b = pd.read_csv(os.path.join(path_b, 'Exp002_CV7409342669_submission.csv'))

# %%
local_sub_a
# Out:
# array([[0.9367676 ],
#        [0.99975586],
#        [0.98461914],
#        ...,
#        [0.3090744 ],
#        [0.89416504],
#        [0.96533203]], dtype=float32)

# %%
local_sub_b
# Out:
# array([[-0.5142043 ,  0.745507  ],
#        [-2.4642305 ,  2.6231143 ],
#        [-0.7344978 ,  0.75612056],
#        ...,
#        [ 0.3883587 , -0.71089435],
#        [-0.37253785,  0.3135999 ],
#        [ 0.67611504, -0.6196541 ]], dtype=float32)
